# %% [markdown]
# 🚀 Project 1: Student Marks Prediction

# %%
# Libraries Import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Making Data
data = {
    "study_hours": [1,2,3,4,5,6,7,8],
    "marks" : [34,40,50,55,65,70,80,90]
}

df = pd.DataFrame(data)
df
# Out:
#    study_hours  marks
# 0            1     34
# 1            2     40
# 2            3     50
# 3            4     55
# 4            5     65
# 5            6     70
# 6            7     80
# 7            8     90

# %%
# Data Visualization
plt.scatter(df["study_hours"], df["marks"])
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Study Hours vs Marks")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# Model training
model = LinearRegression()
model.fit(X, y)

# Prediction (correct way)
new_data = pd.DataFrame({
    "study_hours": [5]
})

pred = model.predict(new_data)
print("5 ghante padhne par marks:", pred[0])
# Out:
# 5 ghante padhne par marks: 64.4404761904762

# %%
plt.scatter(X, y)
plt.plot(X, model.predict(X))
plt.show()
