# %% [markdown]
# # Python Basics
# ## Data Science Learning Journey
# Author: Adarsh Kumar Hembrom

# %%
print("Starting my Data Science journey 🚀")
# Out:
# Starting my Data Science journey 🚀

# %%
a = 3
a
# Out:
# 3

# %% [markdown]
# Variable are the placeholder where we will keep variety of data which we can use to write logic

# %%
type(a)
# Out:
# int

# %%
b= 4.5
type(b)
# Out:
# float

# %%
Adarsh = 4
Adarsh
# Out:
# 4

# %%
a = "Adarsh"

# %%
type(a)
# Out:
# str

# %%
d = True

# %%
type(d)
# Out:
# bool

# %%
a = False
type(a)
# Out:
# bool

# %%
True+False
# Out:
# 1

# %%
True-False
# Out:
# 1

# %% [markdown]
# True / False -> It will throw Error

# %% [markdown]
# True / False -> It will Throw Error

# %%
c = 5+6j

# %%
type(c)
# Out:
# complex

# %%
c.real
# Out:
# 5.0

# %%
c.imag
# Out:
# 6.0

# %% [markdown]
# Rules for declaring a variable

# %%
5 = a
# Out:
#   Cell In[20], line 1
#     5 = a
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
1name = "Learning python"
# Out:
#   Cell In[21], line 1
#     1name = "Learning python"
#     ^
# SyntaxError: invalid decimal literal

# %%
abc = 35

# %%
abc
# Out:
# 35

# %%
_name = "Adarsh"
_name
# Out:
# 'Adarsh'

# %%
location = "Delhi"

# %%
location
# Out:
# 'Delhi'

# %%
data-science = "Learning" #invalid
# Out:
#   Cell In[27], line 1
#     data-science = "Learning"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
_abc =2 #valid
I12 = 43 #valid
data_analytics  = "Power Bi Learning" #valid

# %%
#this is single
#line comment

# %%
"""this 
is multi 
line comment 
"""
# Out:
# 'this \nis multi \nline comment \n'

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
a = 34
print(a)
# Out:
# 34
